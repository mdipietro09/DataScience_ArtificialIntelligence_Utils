# %% [markdown]
# # Computer Vision - Object Detection and Classification example

# %% [markdown]
# ###### Fashion dataset (Kaggle)  https://www.kaggle.com/datafiniti/womens-shoes-prices

# %% [markdown]
# ### 0 - Setup

# %% [markdown]
# ###### Import pckgs

# %%
import warnings
warnings.filterwarnings("ignore")
from cv_utils import *

# %% [markdown]
# ###### Import data

# %%
# Reading the csv with price and image url
import csv

with open('data/data.csv', 'r') as file:
    table = csv.reader(file, delimiter=',')
    
    ## skip headers
    next(table, None)
    
    ## some items are the same, I'll keep the unique values (653 rows)
    lst_id, data = [], []
    for row in table:
        if row[0] not in lst_id:
            lst_id.append(row[0])
            price = float(row[16])
            price_class = "0_50" if (price <= 50) else ("over100" if (price > 100) else "50_100")
            data.append({"url":row[10], "price":price, "price_class":price_class})
        else:
            next
    
    ## insert a custom id
    for i,dic in enumerate(data):
        dic["id"]=i
        
print("len:", len(data))
data[0]
# Out:
# len: 653
# {'url': 'https://i5.walmartimages.com/asr/861ca6cf-fa55-4a48-904d-b764d7c00f0c_1.1a2bb39923e1486d05bdafe37ad832e3.jpeg?odnHeight=450&odnWidth=450&odnBg=FFFFFF,https://i5.walmartimages.com/asr/efe9ba1e-daed-4534-9e2e-11804bbb30f1_1.62e3e7f0268f641323a245d5caebdd6d.jpeg?odnHeight=450&odnWidth=450&odnBg=FFFFFF,https://i5.walmartimages.com/asr/0c717815-228e-4c9b-a8fc-d033576461c9_1.f08402e0a5165746e133ddeb589c73e0.jpeg?odnHeight=450&odnWidth=450&odnBg=FFFFFF,https://i5.walmartimages.com/asr/f46703c8-2cdb-4bf2-a3ea-819f24aab134_1.df725b76ca0112d64bdf566ad97760a9.jpeg?odnHeight=450&odnWidth=450&odnBg=FFFFFF,https://i5.walmartimages.com/asr/f652f354-a1fb-47ac-b507-7f97eb216b14_1.39e78b87e2328421803115869ee8b950.jpeg?odnHeight=450&odnWidth=450&odnBg=FFFFFF,http://ak1.ostkcdn.com/images/products/84/146/P16141204.jpg,http://s1.shoes.com/images/br021/womens-naturalizer-danya-soft-silver-crosshatch-shiny-377672_366_tp.jpg,http://s3.shoes.com/images/br021/womens-naturalizer-danya-soft-silver-crosshatch-shiny-377672_366_sl.jpg,http://s2.shoes.com/images/br021/womens-naturalizer-danya-soft-silver-crosshatch-shiny-377672_366_rt.jpg,http://s3.shoes.com/images/br021/womens-naturalizer-danya-soft-silver-crosshatch-shiny-377672_366_45.jpg,http://s2.shoes.com/images/br021/womens-naturalizer-danya-soft-silver-crosshatch-shiny-377672_366_hl.jpg,http://s1.shoes.com/images/br021/womens-naturalizer-danya-soft-silver-crosshatch-shiny-377672_366_lt.jpg,http://ak1.ostkcdn.com/images/products/85/115/P16454357.jpg',
#  'price': 55.99,
#  'price_class': '50_100',
#  'id': 0}

# %%
# Create the file system structure
import os

lst_folders = ["raw_images", "pretrained_models",
               "training_yolo/train/images", "training_yolo/train/annotations",
               "training_yolo/validation/images", "training_yolo/validation/annotations",
               "training_cnn/train/0_50", "training_cnn/train/50_100", "training_cnn/train/over100",
               "training_cnn/validation/0_50", "training_cnn/validation/50_100", "training_cnn/validation/over100"
               ]
for folder in lst_folders:
    if not os.path.exists("fs/"+folder):
        os.makedirs("fs/"+folder)

## print folder structure
for root, dirs, files in os.walk("fs"):
    path = root.split(os.sep)
    print((len(path) - 1) * ' -', os.path.basename(root))
    for file in files:
        print(len(path) * '  ', file)
# Out:
#  fs
#  - pretrained_models
#      detection_config.json
#      yolo_base.h5
#      yolo_shoes_nopreprocess.h5
#  - raw_images
#  - training_cnn
#  - - train
#  - - - 0_50
#  - - - 50_100
#  - - - over100
#  - - validation
#  - - - 0_50
#  - - - 50_100
#  - - - over100
#  - training_yolo
#  - - train
#  - - - annotations
#  - - - images
#  - - validation
#  - - - annotations
#  - - - images

# %%
# Scraping the imgaes from the web and downloading on file system
import requests

for dic in data:
    try:
        res = requests.get(dic["url"])
        if res.status_code == 200:
            file_name = str(dic["id"])+'.jpg'
            file = open("fs/raw_images/"+file_name,'wb')
            file.write(res.content)
            file.close()
            
    except Exception as e:
        print("failed on:", dic["id"], "| res:", res.status_code, " | error:", e)
        next

# %%
# Load all images
lst_imgs = load_imgs(dirpath="fs/raw_images/", plot=True, ext=['.png','.jpg','.jpeg','.JPG'])
print("shape:", lst_imgs[0].shape)
# Out:
# shape: (1000, 1000, 3)

# %%
# Load Validation images
lst_new_imgs = load_imgs(dirpath="data/")
plot_imgs(lst_new_imgs, lst_titles=["Level:easy, Price:135", "Level:medium, Price:137", "Level:hard, Price:200"], figsize=(10,5))

# %% [markdown]
# ### 1 - Image Analysis

# %% [markdown]
# ###### Target Variable

# %%
y = [dic["price"] for dic in data]

print("len:", len(y))
print("mean:", np.mean(y))

fig, ax = plt.subplots(figsize=(10,3))
ax.hist(y, bins=100)
ax.set(xlabel='price', ylabel="count")
plt.show()
# Out:
# len: 653
# mean: 59.81194486983154

# %%
y = [dic["price_class"] for dic in data]

fig, ax = plt.subplots(figsize=(5,3))
ax.hist(y)
ax.set(xlabel='price class', ylabel="count")
plt.show()

# %% [markdown]
# ###### Size

# %%
sizes = [i.shape[0] for i in lst_imgs]

fig, ax = plt.subplots(figsize=(10,3))
ax.hist(sizes, bins=10)
ax.set(xlabel='sizes', ylabel="count")
plt.show()

# %% [markdown]
# ###### Colors

# %%
utils_color_distributions(lst_imgs, y, figsize=(10,10))

# %% [markdown]
# ### 2 - Preprocessing for Classification

# %% [markdown]
# ###### Partitioning

# %%
# Copying images into train / test folders.
import shutil

split = int(len(data)*0.80)

for i,dic in enumerate(data):
    try:
        filename = str(dic["id"])+'.jpg'
        file = "fs/raw_images/"+filename
        folder = "train/" if i < split else "validation/"
        shutil.copyfile(src="fs/raw_images/"+filename, dst="fs/training_cnn/"+folder+dic["price_class"]+"/"+filename)
        
    except Exception as e:
        print("failed on:", dic["id"], " | error:", e)
        next
# Out:
# failed on: 4  | error: [Errno 2] No such file or directory: 'fs/raw_images/4.jpg'
# failed on: 531  | error: [Errno 2] No such file or directory: 'fs/raw_images/531.jpg'
# failed on: 532  | error: [Errno 2] No such file or directory: 'fs/raw_images/532.jpg'
# failed on: 533  | error: [Errno 2] No such file or directory: 'fs/raw_images/533.jpg'
# failed on: 534  | error: [Errno 2] No such file or directory: 'fs/raw_images/534.jpg'
# failed on: 535  | error: [Errno 2] No such file or directory: 'fs/raw_images/535.jpg'
# failed on: 536  | error: [Errno 2] No such file or directory: 'fs/raw_images/536.jpg'
# failed on: 537  | error: [Errno 2] No such file or directory: 'fs/raw_images/537.jpg'
# failed on: 538  | error: [Errno 2] No such file or directory: 'fs/raw_images/538.jpg'
# failed on: 539  | error: [Errno 2] No such file or directory: 'fs/raw_images/539.jpg'
# failed on: 540  | error: [Errno 2] No such file or directory: 'fs/raw_images/540.jpg'
# failed on: 541  | error: [Errno 2] No such file or directory: 'fs/raw_images/541.jpg'
# failed on: 542  | error: [Errno 2] No such file or directory: 'fs/raw_images/542.jpg'
# failed on: 544  | error: [Errno 2] No such file or directory: 'fs/raw_images/544.jpg'
# failed on: 545  | error: [Errno 2] No such file or directory: 'fs/raw_images/545.jpg'
# failed on: 546  | error: [Errno 2] No such file or directory: 'fs/raw_images/546.jpg'
# failed on: 547  | error: [Errno 2] No such file or directory: 'fs/raw_images/547.jpg'
# failed on: 549  | error: [Errno 2] No such file or directory: 'fs/raw_images/549.jpg'
# failed on: 550  | error: [Errno 2] No such file or directory: 'fs/raw_images/550.jpg'
# failed on: 554  | error: [Errno 2] No such file or directory: 'fs/raw_images/554.jpg'
# failed on: 555  | error: [Errno 2] No such file or directory: 'fs/raw_images/555.jpg'
# failed on: 556  | error: [Errno 2] No such file or directory: 'fs/raw_images/556.jpg'
# failed on: 558  | error: [Errno 2] No such file or directory: 'fs/raw_images/558.jpg'
# failed on: 559  | error: [Errno 2] No such file or directory: 'fs/raw_images/559.jpg'
# failed on: 560  | error: [Errno 2] No such file or directory: 'fs/raw_images/560.jpg'
# failed on: 561  | error: [Errno 2] No such file or directory: 'fs/raw_images/561.jpg'
# failed on: 562  | error: [Errno 2] No such file or directory: 'fs/raw_images/562.jpg'
# failed on: 563  | error: [Errno 2] No such file or directory: 'fs/raw_images/563.jpg'
# failed on: 564  | error: [Errno 2] No such file or directory: 'fs/raw_images/564.jpg'
# failed on: 565  | error: [Errno 2] No such file or directory: 'fs/raw_images/565.jpg'
# failed on: 566  | error: [Errno 2] No such file or directory: 'fs/raw_images/566.jpg'
# failed on: 567  | error: [Errno 2] No such file or directory: 'fs/raw_images/567.jpg'
# failed on: 568  | error: [Errno 2] No such file or directory: 'fs/raw_images/568.jpg'
# failed on: 569  | error: [Errno 2] No such file or directory: 'fs/raw_images/569.jpg'
# failed on: 570  | error: [Errno 2] No such file or directory: 'fs/raw_images/570.jpg'
# failed on: 571  | error: [Errno 2] No such file or directory: 'fs/raw_images/571.jpg'
# failed on: 572  | error: [Errno 2] No such file or directory: 'fs/raw_images/572.jpg'
# failed on: 573  | error: [Errno 2] No such file or directory: 'fs/raw_images/573.jpg'
# failed on: 574  | error: [Errno 2] No such file or directory: 'fs/raw_images/574.jpg'
# failed on: 575  | error: [Errno 2] No such file or directory: 'fs/raw_images/575.jpg'
# failed on: 576  | error: [Errno 2] No such file or directory: 'fs/raw_images/576.jpg'
# failed on: 578  | error: [Errno 2] No such file or directory: 'fs/raw_images/578.jpg'
# failed on: 579  | error: [Errno 2] No such file or directory: 'fs/raw_images/579.jpg'
# failed on: 580  | error: [Errno 2] No such file or directory: 'fs/raw_images/580.jpg'
# failed on: 581  | error: [Errno 2] No such file or directory: 'fs/raw_images/581.jpg'
# failed on: 582  | error: [Errno 2] No such file or directory: 'fs/raw_images/582.jpg'
# failed on: 583  | error: [Errno 2] No such file or directory: 'fs/raw_images/583.jpg'
# failed on: 584  | error: [Errno 2] No such file or directory: 'fs/raw_images/584.jpg'
# failed on: 585  | error: [Errno 2] No such file or directory: 'fs/raw_images/585.jpg'
# failed on: 586  | error: [Errno 2] No such file or directory: 'fs/raw_images/586.jpg'
# failed on: 587  | error: [Errno 2] No such file or directory: 'fs/raw_images/587.jpg'
# failed on: 588  | error: [Errno 2] No such file or directory: 'fs/raw_images/588.jpg'
# failed on: 589  | error: [Errno 2] No such file or directory: 'fs/raw_images/589.jpg'
# failed on: 590  | error: [Errno 2] No such file or directory: 'fs/raw_images/590.jpg'
# failed on: 592  | error: [Errno 2] No such file or directory: 'fs/raw_images/592.jpg'
# failed on: 594  | error: [Errno 2] No such file or directory: 'fs/raw_images/594.jpg'
# failed on: 595  | error: [Errno 2] No such file or directory: 'fs/raw_images/595.jpg'
# failed on: 596  | error: [Errno 2] No such file or directory: 'fs/raw_images/596.jpg'
# failed on: 597  | error: [Errno 2] No such file or directory: 'fs/raw_images/597.jpg'
# failed on: 598  | error: [Errno 2] No such file or directory: 'fs/raw_images/598.jpg'
# failed on: 599  | error: [Errno 2] No such file or directory: 'fs/raw_images/599.jpg'
# failed on: 600  | error: [Errno 2] No such file or directory: 'fs/raw_images/600.jpg'
# failed on: 601  | error: [Errno 2] No such file or directory: 'fs/raw_images/601.jpg'
# failed on: 602  | error: [Errno 2] No such file or directory: 'fs/raw_images/602.jpg'
# failed on: 603  | error: [Errno 2] No such file or directory: 'fs/raw_images/603.jpg'
# failed on: 604  | error: [Errno 2] No such file or directory: 'fs/raw_images/604.jpg'
# failed on: 605  | error: [Errno 2] No such file or directory: 'fs/raw_images/605.jpg'
# failed on: 606  | error: [Errno 2] No such file or directory: 'fs/raw_images/606.jpg'
# failed on: 607  | error: [Errno 2] No such file or directory: 'fs/raw_images/607.jpg'
# failed on: 608  | error: [Errno 2] No such file or directory: 'fs/raw_images/608.jpg'
# failed on: 609  | error: [Errno 2] No such file or directory: 'fs/raw_images/609.jpg'
# failed on: 610  | error: [Errno 2] No such file or directory: 'fs/raw_images/610.jpg'
# failed on: 611  | error: [Errno 2] No such file or directory: 'fs/raw_images/611.jpg'
# failed on: 612  | error: [Errno 2] No such file or directory: 'fs/raw_images/612.jpg'
# failed on: 613  | error: [Errno 2] No such file or directory: 'fs/raw_images/613.jpg'
# failed on: 614  | error: [Errno 2] No such file or directory: 'fs/raw_images/614.jpg'
# failed on: 615  | error: [Errno 2] No such file or directory: 'fs/raw_images/615.jpg'
# failed on: 616  | error: [Errno 2] No such file or directory: 'fs/raw_images/616.jpg'
# failed on: 617  | error: [Errno 2] No such file or directory: 'fs/raw_images/617.jpg'
# failed on: 618  | error: [Errno 2] No such file or directory: 'fs/raw_images/618.jpg'
# failed on: 619  | error: [Errno 2] No such file or directory: 'fs/raw_images/619.jpg'
# failed on: 620  | error: [Errno 2] No such file or directory: 'fs/raw_images/620.jpg'
# failed on: 621  | error: [Errno 2] No such file or directory: 'fs/raw_images/621.jpg'
# failed on: 622  | error: [Errno 2] No such file or directory: 'fs/raw_images/622.jpg'
# failed on: 624  | error: [Errno 2] No such file or directory: 'fs/raw_images/624.jpg'
# failed on: 625  | error: [Errno 2] No such file or directory: 'fs/raw_images/625.jpg'
# failed on: 626  | error: [Errno 2] No such file or directory: 'fs/raw_images/626.jpg'
# failed on: 627  | error: [Errno 2] No such file or directory: 'fs/raw_images/627.jpg'
# failed on: 628  | error: [Errno 2] No such file or directory: 'fs/raw_images/628.jpg'
# failed on: 629  | error: [Errno 2] No such file or directory: 'fs/raw_images/629.jpg'
# failed on: 630  | error: [Errno 2] No such file or directory: 'fs/raw_images/630.jpg'
# failed on: 631  | error: [Errno 2] No such file or directory: 'fs/raw_images/631.jpg'
# failed on: 632  | error: [Errno 2] No such file or directory: 'fs/raw_images/632.jpg'
# failed on: 633  | error: [Errno 2] No such file or directory: 'fs/raw_images/633.jpg'
# failed on: 635  | error: [Errno 2] No such file or directory: 'fs/raw_images/635.jpg'
# failed on: 636  | error: [Errno 2] No such file or directory: 'fs/raw_images/636.jpg'
# failed on: 637  | error: [Errno 2] No such file or directory: 'fs/raw_images/637.jpg'
# failed on: 638  | error: [Errno 2] No such file or directory: 'fs/raw_images/638.jpg'
# failed on: 639  | error: [Errno 2] No such file or directory: 'fs/raw_images/639.jpg'
# failed on: 640  | error: [Errno 2] No such file or directory: 'fs/raw_images/640.jpg'
# failed on: 641  | error: [Errno 2] No such file or directory: 'fs/raw_images/641.jpg'
# failed on: 642  | error: [Errno 2] No such file or directory: 'fs/raw_images/642.jpg'
# failed on: 643  | error: [Errno 2] No such file or directory: 'fs/raw_images/643.jpg'
# failed on: 644  | error: [Errno 2] No such file or directory: 'fs/raw_images/644.jpg'
# failed on: 645  | error: [Errno 2] No such file or directory: 'fs/raw_images/645.jpg'
# failed on: 646  | error: [Errno 2] No such file or directory: 'fs/raw_images/646.jpg'
# failed on: 647  | error: [Errno 2] No such file or directory: 'fs/raw_images/647.jpg'
# failed on: 648  | error: [Errno 2] No such file or directory: 'fs/raw_images/648.jpg'
# failed on: 649  | error: [Errno 2] No such file or directory: 'fs/raw_images/649.jpg'
# failed on: 651  | error: [Errno 2] No such file or directory: 'fs/raw_images/651.jpg'

# %% [markdown]
# ###### Features Engineering

# %%
from tensorflow.keras import preprocessing

ImageGen = preprocessing.image.ImageDataGenerator(rotation_range=30, width_shift_range=0.1, height_shift_range=0.1,
                                                  rescale=1./255, shear_range=0.2, zoom_range=0.2,
                                                  horizontal_flip=True, fill_mode='nearest')

# %%
plot_imgs([lst_imgs[0], ImageGen.random_transform(lst_imgs[0])], ["Original","Generator"], figsize=(8,3))

# %%
## Train
print("--- Train ---")
X_train = ImageGen.flow_from_directory(directory="fs/training_cnn/train", target_size=(256,256), color_mode='rgb', 
                                       classes=None, class_mode='categorical', shuffle=True, batch_size=32)

## Test
print("--- Test ---")
X_test = ImageGen.flow_from_directory(directory="fs/training_cnn/validation", target_size=(256,256), color_mode='rgb', 
                                      classes=None, class_mode='categorical', shuffle=True, batch_size=32)
# Out:
# --- Train ---
# Found 521 images belonging to 3 classes.
# --- Test ---
# Found 22 images belonging to 3 classes.

# %%
print(X_train.class_indices)

dic_y_mapping = {v:k for k,v in X_train.class_indices.items()}
print(dic_y_mapping)
# Out:
# {'0_50': 0, '50_100': 1, 'over100': 2}
# {0: '0_50', 1: '50_100', 2: 'over100'}

# %% [markdown]
# ### 3 - Model Desing & Testing (CNN for classification: training from scratch)

# %% [markdown]
# ###### Train

# %%
## CNN
### layer 1 conv 5x5 (32 neurons) + pool 2x2
model = models.Sequential()
model.add( layers.Conv2D(input_shape=(256,256,3), kernel_size=(5,5), filters=32, strides=(1,1), padding="valid", activation='relu') )
model.add( layers.MaxPooling2D(pool_size=(2,2), padding="valid") )
### layer 2 conv 3x3 (64 neurons) + pool 2x2
model.add( layers.Conv2D(kernel_size=(3,3), filters=64, strides=(1,1), padding="valid", activation='relu') )
model.add( layers.MaxPooling2D(pool_size=(2,2), padding="valid") )
### layer 3 fully connected (128 neuroni)
model.add( layers.Flatten() )
model.add( layers.Dense(units=128, activation="relu") )
model.add( layers.Dropout(rate=0.2) )
## layer output
model.add( layers.Dense(units=3, activation="softmax") )
model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
# Out:
# WARNING:tensorflow:From C:\profili\u382270\Downloads\MyStuff\anaconda2\envs\env1\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\profili\u382270\Downloads\MyStuff\anaconda2\envs\env1\lib\site-packages\tensorflow\python\keras\layers\core.py:143: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
# this takes a while
cnn = fit_cnn(X_train, X_test, model=None, batch_size=32, epochs=10, savepath="fs/pretrained_models/")
# Out:
# y multiclasses --> output layer:  3 neurons with 'softmax' activation and 'categorical_crossentropy' loss
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 252, 252, 32)      2432
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 126, 126, 32)      0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 124, 124, 64)      18496
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 62, 62, 64)        0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 246016)            0
# _________________________________________________________________
# dense_6 (Dense)              (None, 128)               31490176
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 3)                 387
# =================================================================
# Total params: 31,511,491
# Trainable params: 31,511,491
# Non-trainable params: 0
# _________________________________________________________________
# None
# 1/1 [==============================] - 3s 3s/step - loss: 12.4549 - acc: 0.2273
# 1/1 [==============================] - 2s 2s/step - loss: 12.4549 - acc: 0.2273
# 1/1 [==============================] - 3s 3s/step - loss: 12.4549 - acc: 0.2273
# 1/1 [==============================] - 2s 2s/step - loss: 12.4549 - acc: 0.2273
# 1/1 [==============================] - 2s 2s/step - loss: 12.4549 - acc: 0.2273
# 1/1 [==============================] - 2s 2s/step - loss: 12.4549 - acc: 0.2273
# 1/1 [==============================] - 2s 2s/step - loss: 12.4549 - acc: 0.2273
# 1/1 [==============================] - 2s 2s/step - loss: 12.4549 - acc: 0.2273
# 1/1 [==============================] - 2s 2s/step - loss: 12.4549 - acc: 0.2273
# 1/1 [==============================] - 2s 2s/step - loss: 12.4549 - acc: 0.2273

# %% [markdown]
# ###### Evaluate

# %% [markdown]
# ### 4 - Model Desing & Testing (CNN for classification: transfer learning)

# %% [markdown]
# ###### Train

# %%
# Base model
base = applications.resnet50.ResNet50(weights='imagenet', include_top=False, input_shape=(256,256,3))
for layer in base.layers:
    layer.trainable = False

# %%
# Adding layers
new_layer = base.output
new_layer = layers.Flatten()(new_layer)
new_layer = layers.Dense(units=1024, activation='relu')(new_layer)
new_layer = layers.Dropout(rate=0.5)(new_layer)
new_layer = layers.Dense(units=3, activation="softmax")(new_layer)

# %%
# this takes a while
cnn_trf = fit_cnn_transfer_learning(X_train, X_test, base=base, new_layer=new_layer, batch_size=32, epochs=10, 
                                    savepath="fs/pretrained_models/")
# Out:
# --- check ---
# Base model requires input of shape: (256, 256, 3)
# X shape: (256, 256, 3)
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 256, 256, 3)  0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 262, 262, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 128, 128, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalizationV1) (None, 128, 128, 64) 256         conv1[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 128, 128, 64) 0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 130, 130, 64) 0           activation[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 64, 64, 64)   0           pool1_pad[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a (Conv2D)         (None, 64, 64, 64)   4160        max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a (BatchNormalizati (None, 64, 64, 64)   256         res2a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 64, 64, 64)   0           bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b (Conv2D)         (None, 64, 64, 64)   36928       activation_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b (BatchNormalizati (None, 64, 64, 64)   256         res2a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 64, 64, 64)   0           bn2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch2c (Conv2D)         (None, 64, 64, 256)  16640       activation_2[0][0]
# __________________________________________________________________________________________________
# res2a_branch1 (Conv2D)          (None, 64, 64, 256)  16640       max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c (BatchNormalizati (None, 64, 64, 256)  1024        res2a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn2a_branch1 (BatchNormalizatio (None, 64, 64, 256)  1024        res2a_branch1[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 64, 64, 256)  0           bn2a_branch2c[0][0]
#                                                                  bn2a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 64, 64, 256)  0           add[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a (Conv2D)         (None, 64, 64, 64)   16448       activation_3[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2a (BatchNormalizati (None, 64, 64, 64)   256         res2b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 64, 64, 64)   0           bn2b_branch2a[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b (Conv2D)         (None, 64, 64, 64)   36928       activation_4[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2b (BatchNormalizati (None, 64, 64, 64)   256         res2b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 64, 64, 64)   0           bn2b_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b_branch2c (Conv2D)         (None, 64, 64, 256)  16640       activation_5[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2c (BatchNormalizati (None, 64, 64, 256)  1024        res2b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 64, 64, 256)  0           bn2b_branch2c[0][0]
#                                                                  activation_3[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 64, 64, 256)  0           add_1[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a (Conv2D)         (None, 64, 64, 64)   16448       activation_6[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2a (BatchNormalizati (None, 64, 64, 64)   256         res2c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 64, 64, 64)   0           bn2c_branch2a[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b (Conv2D)         (None, 64, 64, 64)   36928       activation_7[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2b (BatchNormalizati (None, 64, 64, 64)   256         res2c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 64, 64, 64)   0           bn2c_branch2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2c (Conv2D)         (None, 64, 64, 256)  16640       activation_8[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2c (BatchNormalizati (None, 64, 64, 256)  1024        res2c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 64, 64, 256)  0           bn2c_branch2c[0][0]
#                                                                  activation_6[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 64, 64, 256)  0           add_2[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a (Conv2D)         (None, 32, 32, 128)  32896       activation_9[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a (BatchNormalizati (None, 32, 32, 128)  512         res3a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 32, 32, 128)  0           bn3a_branch2a[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b (Conv2D)         (None, 32, 32, 128)  147584      activation_10[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b (BatchNormalizati (None, 32, 32, 128)  512         res3a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 32, 32, 128)  0           bn3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch2c (Conv2D)         (None, 32, 32, 512)  66048       activation_11[0][0]
# __________________________________________________________________________________________________
# res3a_branch1 (Conv2D)          (None, 32, 32, 512)  131584      activation_9[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2c (BatchNormalizati (None, 32, 32, 512)  2048        res3a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn3a_branch1 (BatchNormalizatio (None, 32, 32, 512)  2048        res3a_branch1[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 32, 32, 512)  0           bn3a_branch2c[0][0]
#                                                                  bn3a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 32, 32, 512)  0           add_3[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a (Conv2D)         (None, 32, 32, 128)  65664       activation_12[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2a (BatchNormalizati (None, 32, 32, 128)  512         res3b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 32, 32, 128)  0           bn3b_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b (Conv2D)         (None, 32, 32, 128)  147584      activation_13[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2b (BatchNormalizati (None, 32, 32, 128)  512         res3b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 32, 32, 128)  0           bn3b_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b_branch2c (Conv2D)         (None, 32, 32, 512)  66048       activation_14[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2c (BatchNormalizati (None, 32, 32, 512)  2048        res3b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 32, 32, 512)  0           bn3b_branch2c[0][0]
#                                                                  activation_12[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 32, 32, 512)  0           add_4[0][0]
# __________________________________________________________________________________________________
# res3c_branch2a (Conv2D)         (None, 32, 32, 128)  65664       activation_15[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2a (BatchNormalizati (None, 32, 32, 128)  512         res3c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 32, 32, 128)  0           bn3c_branch2a[0][0]
# __________________________________________________________________________________________________
# res3c_branch2b (Conv2D)         (None, 32, 32, 128)  147584      activation_16[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2b (BatchNormalizati (None, 32, 32, 128)  512         res3c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 32, 32, 128)  0           bn3c_branch2b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2c (Conv2D)         (None, 32, 32, 512)  66048       activation_17[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2c (BatchNormalizati (None, 32, 32, 512)  2048        res3c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 32, 32, 512)  0           bn3c_branch2c[0][0]
#                                                                  activation_15[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 32, 32, 512)  0           add_5[0][0]
# __________________________________________________________________________________________________
# res3d_branch2a (Conv2D)         (None, 32, 32, 128)  65664       activation_18[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2a (BatchNormalizati (None, 32, 32, 128)  512         res3d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 32, 32, 128)  0           bn3d_branch2a[0][0]
# __________________________________________________________________________________________________
# res3d_branch2b (Conv2D)         (None, 32, 32, 128)  147584      activation_19[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2b (BatchNormalizati (None, 32, 32, 128)  512         res3d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 32, 32, 128)  0           bn3d_branch2b[0][0]
# __________________________________________________________________________________________________
# res3d_branch2c (Conv2D)         (None, 32, 32, 512)  66048       activation_20[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2c (BatchNormalizati (None, 32, 32, 512)  2048        res3d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 32, 32, 512)  0           bn3d_branch2c[0][0]
#                                                                  activation_18[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 32, 32, 512)  0           add_6[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a (Conv2D)         (None, 16, 16, 256)  131328      activation_21[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2a (BatchNormalizati (None, 16, 16, 256)  1024        res4a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 16, 16, 256)  0           bn4a_branch2a[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b (Conv2D)         (None, 16, 16, 256)  590080      activation_22[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2b (BatchNormalizati (None, 16, 16, 256)  1024        res4a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 16, 16, 256)  0           bn4a_branch2b[0][0]
# __________________________________________________________________________________________________
# res4a_branch2c (Conv2D)         (None, 16, 16, 1024) 263168      activation_23[0][0]
# __________________________________________________________________________________________________
# res4a_branch1 (Conv2D)          (None, 16, 16, 1024) 525312      activation_21[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2c (BatchNormalizati (None, 16, 16, 1024) 4096        res4a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn4a_branch1 (BatchNormalizatio (None, 16, 16, 1024) 4096        res4a_branch1[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 16, 16, 1024) 0           bn4a_branch2c[0][0]
#                                                                  bn4a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 16, 16, 1024) 0           add_7[0][0]
# __________________________________________________________________________________________________
# res4b_branch2a (Conv2D)         (None, 16, 16, 256)  262400      activation_24[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2a (BatchNormalizati (None, 16, 16, 256)  1024        res4b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 16, 16, 256)  0           bn4b_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b_branch2b (Conv2D)         (None, 16, 16, 256)  590080      activation_25[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2b (BatchNormalizati (None, 16, 16, 256)  1024        res4b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 16, 16, 256)  0           bn4b_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b_branch2c (Conv2D)         (None, 16, 16, 1024) 263168      activation_26[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2c (BatchNormalizati (None, 16, 16, 1024) 4096        res4b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 16, 16, 1024) 0           bn4b_branch2c[0][0]
#                                                                  activation_24[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 16, 16, 1024) 0           add_8[0][0]
# __________________________________________________________________________________________________
# res4c_branch2a (Conv2D)         (None, 16, 16, 256)  262400      activation_27[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2a (BatchNormalizati (None, 16, 16, 256)  1024        res4c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 16, 16, 256)  0           bn4c_branch2a[0][0]
# __________________________________________________________________________________________________
# res4c_branch2b (Conv2D)         (None, 16, 16, 256)  590080      activation_28[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2b (BatchNormalizati (None, 16, 16, 256)  1024        res4c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 16, 16, 256)  0           bn4c_branch2b[0][0]
# __________________________________________________________________________________________________
# res4c_branch2c (Conv2D)         (None, 16, 16, 1024) 263168      activation_29[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2c (BatchNormalizati (None, 16, 16, 1024) 4096        res4c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 16, 16, 1024) 0           bn4c_branch2c[0][0]
#                                                                  activation_27[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 16, 16, 1024) 0           add_9[0][0]
# __________________________________________________________________________________________________
# res4d_branch2a (Conv2D)         (None, 16, 16, 256)  262400      activation_30[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2a (BatchNormalizati (None, 16, 16, 256)  1024        res4d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 16, 16, 256)  0           bn4d_branch2a[0][0]
# __________________________________________________________________________________________________
# res4d_branch2b (Conv2D)         (None, 16, 16, 256)  590080      activation_31[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2b (BatchNormalizati (None, 16, 16, 256)  1024        res4d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 16, 16, 256)  0           bn4d_branch2b[0][0]
# __________________________________________________________________________________________________
# res4d_branch2c (Conv2D)         (None, 16, 16, 1024) 263168      activation_32[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2c (BatchNormalizati (None, 16, 16, 1024) 4096        res4d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 16, 16, 1024) 0           bn4d_branch2c[0][0]
#                                                                  activation_30[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 16, 16, 1024) 0           add_10[0][0]
# __________________________________________________________________________________________________
# res4e_branch2a (Conv2D)         (None, 16, 16, 256)  262400      activation_33[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2a (BatchNormalizati (None, 16, 16, 256)  1024        res4e_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 16, 16, 256)  0           bn4e_branch2a[0][0]
# __________________________________________________________________________________________________
# res4e_branch2b (Conv2D)         (None, 16, 16, 256)  590080      activation_34[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2b (BatchNormalizati (None, 16, 16, 256)  1024        res4e_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 16, 16, 256)  0           bn4e_branch2b[0][0]
# __________________________________________________________________________________________________
# res4e_branch2c (Conv2D)         (None, 16, 16, 1024) 263168      activation_35[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2c (BatchNormalizati (None, 16, 16, 1024) 4096        res4e_branch2c[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 16, 16, 1024) 0           bn4e_branch2c[0][0]
#                                                                  activation_33[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 16, 16, 1024) 0           add_11[0][0]
# __________________________________________________________________________________________________
# res4f_branch2a (Conv2D)         (None, 16, 16, 256)  262400      activation_36[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2a (BatchNormalizati (None, 16, 16, 256)  1024        res4f_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 16, 16, 256)  0           bn4f_branch2a[0][0]
# __________________________________________________________________________________________________
# res4f_branch2b (Conv2D)         (None, 16, 16, 256)  590080      activation_37[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2b (BatchNormalizati (None, 16, 16, 256)  1024        res4f_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 16, 16, 256)  0           bn4f_branch2b[0][0]
# __________________________________________________________________________________________________
# res4f_branch2c (Conv2D)         (None, 16, 16, 1024) 263168      activation_38[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2c (BatchNormalizati (None, 16, 16, 1024) 4096        res4f_branch2c[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 16, 16, 1024) 0           bn4f_branch2c[0][0]
#                                                                  activation_36[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 16, 16, 1024) 0           add_12[0][0]
# __________________________________________________________________________________________________
# res5a_branch2a (Conv2D)         (None, 8, 8, 512)    524800      activation_39[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2a (BatchNormalizati (None, 8, 8, 512)    2048        res5a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 8, 8, 512)    0           bn5a_branch2a[0][0]
# __________________________________________________________________________________________________
# res5a_branch2b (Conv2D)         (None, 8, 8, 512)    2359808     activation_40[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2b (BatchNormalizati (None, 8, 8, 512)    2048        res5a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 8, 8, 512)    0           bn5a_branch2b[0][0]
# __________________________________________________________________________________________________
# res5a_branch2c (Conv2D)         (None, 8, 8, 2048)   1050624     activation_41[0][0]
# __________________________________________________________________________________________________
# res5a_branch1 (Conv2D)          (None, 8, 8, 2048)   2099200     activation_39[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2c (BatchNormalizati (None, 8, 8, 2048)   8192        res5a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn5a_branch1 (BatchNormalizatio (None, 8, 8, 2048)   8192        res5a_branch1[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 8, 8, 2048)   0           bn5a_branch2c[0][0]
#                                                                  bn5a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 8, 8, 2048)   0           add_13[0][0]
# __________________________________________________________________________________________________
# res5b_branch2a (Conv2D)         (None, 8, 8, 512)    1049088     activation_42[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2a (BatchNormalizati (None, 8, 8, 512)    2048        res5b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 8, 8, 512)    0           bn5b_branch2a[0][0]
# __________________________________________________________________________________________________
# res5b_branch2b (Conv2D)         (None, 8, 8, 512)    2359808     activation_43[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2b (BatchNormalizati (None, 8, 8, 512)    2048        res5b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 8, 8, 512)    0           bn5b_branch2b[0][0]
# __________________________________________________________________________________________________
# res5b_branch2c (Conv2D)         (None, 8, 8, 2048)   1050624     activation_44[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2c (BatchNormalizati (None, 8, 8, 2048)   8192        res5b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 8, 8, 2048)   0           bn5b_branch2c[0][0]
#                                                                  activation_42[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 8, 8, 2048)   0           add_14[0][0]
# __________________________________________________________________________________________________
# res5c_branch2a (Conv2D)         (None, 8, 8, 512)    1049088     activation_45[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2a (BatchNormalizati (None, 8, 8, 512)    2048        res5c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 8, 8, 512)    0           bn5c_branch2a[0][0]
# __________________________________________________________________________________________________
# res5c_branch2b (Conv2D)         (None, 8, 8, 512)    2359808     activation_46[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2b (BatchNormalizati (None, 8, 8, 512)    2048        res5c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 8, 8, 512)    0           bn5c_branch2b[0][0]
# __________________________________________________________________________________________________
# res5c_branch2c (Conv2D)         (None, 8, 8, 2048)   1050624     activation_47[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2c (BatchNormalizati (None, 8, 8, 2048)   8192        res5c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 8, 8, 2048)   0           bn5c_branch2c[0][0]
#                                                                  activation_45[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 8, 8, 2048)   0           add_15[0][0]
# __________________________________________________________________________________________________
# flatten_4 (Flatten)             (None, 131072)       0           activation_48[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 1024)         134218752   flatten_4[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 1024)         0           dense_8[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 3)            3075        dropout_4[0][0]
# ==================================================================================================
# Total params: 157,809,539
# Trainable params: 134,221,827
# Non-trainable params: 23,587,712
# __________________________________________________________________________________________________
# None
# 1/1 [==============================] - 8s 8s/step - loss: 12.4549 - acc: 0.2273
# 1/1 [==============================] - 6s 6s/step - loss: 12.4549 - acc: 0.2273
# 1/1 [==============================] - 6s 6s/step - loss: 12.4549 - acc: 0.2273
# 1/1 [==============================] - 6s 6s/step - loss: 12.4549 - acc: 0.2273
# 1/1 [==============================] - 6s 6s/step - loss: 12.4549 - acc: 0.2273
# 1/1 [==============================] - 6s 6s/step - loss: 12.4549 - acc: 0.2273
# 1/1 [==============================] - 6s 6s/step - loss: 12.4549 - acc: 0.2273
# 1/1 [==============================] - 6s 6s/step - loss: 12.4549 - acc: 0.2273
# 1/1 [==============================] - 6s 6s/step - loss: 12.4549 - acc: 0.2273
# 1/1 [==============================] - 6s 6s/step - loss: 12.4549 - acc: 0.2273

# %% [markdown]
# ###### Evaluate

# %% [markdown]
# ### 5 - Preprocessing for Detection

# %% [markdown]
# ###### Features Engineering

# %%
ex = utils_preprocess_img(lst_imgs[0], resize=256, denoise=True, remove_color=True, morphology=True, segmentation=True, plot=True)

# %%
lst_new_imgs_processed = [utils_preprocess_img(new_img, plot=False, resize=256, denoise=True, 
                                               remove_color=True, morphology=True, segmentation=True) 
                          for new_img in lst_new_imgs]
plot_imgs(lst_new_imgs_processed, lst_titles=["Level:easy, Price:135", "Level:medium, Price:137", "Level:hard, Price:200"], figsize=(15,10))

# %%
#lst_imgs = [utils_preprocess_img(img, resize=256, denoise=True, remove_color=True, morphology=True) for img in lst_imgs]

# %%
# No preprocessing needed

# %% [markdown]
# ###### Partitioning

# %%
split = int(len(lst_imgs)*0.90)

# Train
print("Train: ", split, "images")
save_imgs(lst_imgs=lst_imgs[:split], dirpath="fs/training_yolo/train/images/", i=0)

# Test
print("Test: ", len(lst_imgs)-split, "images")
save_imgs(lst_imgs=lst_imgs[split:], dirpath="fs/training_yolo/validation/images/", i=split)
# Out:
# Train:  488 images
# Test:  55 images

# %% [markdown]
# ###### Create Annotations

# %%
# Check what rectangle measures shall be appropriate
img = lst_imgs[0]
xmin = int(img.shape[0]*0.10)
ymin = int(img.shape[1]*0.10)
xmax = int(img.shape[0]*0.90)
ymax = int(img.shape[1]*0.90)
utils_plot_img(img, mask=None, rect=[(xmin,ymin), (xmax,ymax)], figsize=(5,3))

# %%
# Creating xml annotation file for each image
import xml.etree.cElementTree as XML

def create_annotations(lst_imgs, dirpath_annot, dirpath_img, i=0):
    for img in lst_imgs:
        try:
            img_name, xml_name = str(i)+".jpg", str(i)+".xml"

            ## xml structure
            annotation = XML.Element("annotation")
            XML.SubElement(annotation, "folder").text = "images"
            XML.SubElement(annotation, "filename").text = img_name
            XML.SubElement(annotation, "path").text = dirpath_img+img_name

            source = XML.SubElement(annotation, "source")
            XML.SubElement(source, "database").text = "Unknown"

            size = XML.SubElement(annotation, "size")
            XML.SubElement(size, "width").text = str(img.shape[0])
            XML.SubElement(size, "height").text = str(img.shape[1])
            XML.SubElement(size, "depth").text = str(img.shape[2])

            XML.SubElement(annotation, "segmented").text = "0"

            object = XML.SubElement(annotation, "object")
            XML.SubElement(object, "name").text = "shoes"
            XML.SubElement(object, "pose").text = "Unspecified"
            XML.SubElement(object, "truncated").text = "0"
            XML.SubElement(object, "difficult").text = "0"
            bndbox = XML.SubElement(object, "bndbox")
            XML.SubElement(bndbox, "xmin").text = str(int(img.shape[0]*0.10))
            XML.SubElement(bndbox, "ymin").text = str(int(img.shape[1]*0.10))
            XML.SubElement(bndbox, "xmax").text = str(int(img.shape[0]*0.90))
            XML.SubElement(bndbox, "ymax").text = str(int(img.shape[1]*0.90))

            ## write xml
            xml_file = XML.ElementTree(annotation)
            xml_file.write(dirpath_annot+xml_name)
            i += 1

        except Exception as e:
            print("failed on:", i, "| error:", e)
            i += 1
            pass

# %%
# Train
create_annotations(lst_imgs[:split], dirpath_annot="fs/training_yolo/train/annotations/", 
                                     dirpath_img="fs/training_yolo/train/images/", i=0)
# Test
create_annotations(lst_imgs[split:], dirpath_annot="fs/training_yolo/validation/annotations/", 
                                     dirpath_img="fs/training_yolo/validation/images/", i=split)
# Out:
# failed on: 90 | error: tuple index out of range

# %%
file = XML.parse("fs/training_yolo/train/annotations/0.xml")
root = file.getroot()
print(root.tag)
for elem in root:
    print(" ", elem.tag, ":", elem.text)
    if len(elem.getchildren()) > 0:
        for subelem in elem:
            print("   - ", subelem.tag, ":", subelem.text)
            if len(subelem.getchildren()) > 0:
                for subsubelem in subelem:
                    print("     - ", subsubelem.tag, ":", subsubelem.text)
# Out:
# annotation
#   folder : images
#   filename : 0.jpg
#   path : fs/training_yolo/train/images/0.jpg
#   source : None
#    -  database : Unknown
#   size : None
#    -  width : 1000
#    -  height : 1000
#    -  depth : 3
#   segmented : 0
#   object : None
#    -  name : shoes
#    -  pose : Unspecified
#    -  truncated : 0
#    -  difficult : 0
#    -  bndbox : None
#      -  xmin : 100
#      -  ymin : 100
#      -  xmax : 900
#      -  ymax : 900

# %% [markdown]
# ### 6 - Model Desing & Testing (YOLO for detection)

# %% [markdown]
# ###### Train

# %%
# this takes 10 hours
yolo = train_yolo(lst_y=["shoes"], train_path="fs/training_yolo/", transfer_modelfile="fs/pretrained_models/yolo_base.h5")
# Out:
# Generating anchor boxes for training images and annotation...
# Average IOU for 9 anchors: 1.00
# Anchor Boxes generated.
# Detection configuration saved in  fs/training_yolo/json\detection_config.json
# --- training ---
# Training on: 	['shoes']
# Training with Batch Size:  4
# Number of Experiments:  1
# WARNING:tensorflow:From C:\profili\u382270\Downloads\MyStuff\anaconda2\envs\env1\lib\site-packages\imageai\Detection\Custom\yolo.py:24: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Training with transfer learning from pretrained Model
# Epoch 1/1
# 976/976 [==============================] - 27861s 29s/step - loss: 25.9413 - yolo_layer_1_loss: 7.7407 - yolo_layer_2_loss: 4.1500 - yolo_layer_3_loss: 14.0506 - val_loss: 2.1288 - val_yolo_layer_1_loss: 5.6893 - val_yolo_layer_2_loss: 0.0201 - val_yolo_layer_3_loss: 0.2659
# --- metrics ---
# Starting Model evaluation....
# Model File:  fs/training_yolo/models\detection_model-ex-001--loss-0025.941.h5
#
# Using IoU :  0.5
# Using Object Threshold :  0.5
# Using Non-Maximum Suppression :  0.5
# shoes: 0.6436
# mAP: 0.6436
# ===============================
# [{'model_file': 'fs/training_yolo/models\\detection_model-ex-001--loss-0025.941.h5', 'using_iou': 0.5, 'using_object_threshold': 0.5, 'using_non_maximum_suppression': 0.5, 'average_precision': {'shoes': 0.6435572623980963}, 'map': 0.6435572623980963}]
# --- loading model ---

# %%
#yolo = load_yolo(modelfile="fs/pretrained_models/yolo_shoes_nopreprocess.h5", 
#                 confjson="fs/pretrained_models/detection_config.json")

# %% [markdown]
# ###### Evaluate

# %% [markdown]
# ### 7 - Putting all together: classification of detected objects

# %% [markdown]
# ###### Detect

# %%
yolo_predicted = [obj_detect_yolo(new_img, yolo, min_prob=60) for new_img in lst_new_imgs]

# %%
full_imgs = [i[0] for i in yolo_predicted]
plot_imgs(full_imgs, lst_titles=["Level:easy, Price:135", "Level:medium, Price:137", "Level:hard, Price:200"], figsize=(15,10))

# %% [markdown]
# ###### Classify

# %%
cropped_imgs = [i[2] for i in yolo_predicted]
plot_imgs(cropped_imgs, lst_titles=["Level:easy, Price:135", "Level:medium, Price:137", "Level:hard, Price:200"], figsize=(10,5))

# %%
dic_y_mapping
# Out:
# {0: '0_50', 1: '50_100', 2: 'over100'}

# %%
for x in cropped_imgs:
    shape = cnn.input_shape[1]
    x = cv2.resize(x, (shape,shape), interpolation=cv2.INTER_LINEAR)
    x = np.expand_dims(x, axis=0)
    predicted_prob = cnn.predict(x)
    predicted = [dic_y_mapping[np.argmax(pred)] for pred in predicted_prob]
    print("predicted:", predicted[0])
# Out:
# predicted: 0_50
# predicted: 0_50
# predicted: 0_50
